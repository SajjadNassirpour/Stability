# %% [markdown]
# # Code Description

# %%
              
                 ##-----****---"On the Stability Region of Intermittent Interference Networks"---****-----##
        
            ##---- This code simulates the results of "homogeneous settings when 0=<delta=<(3-\sqrt(5))/2" ----##
            
             ##---- This code describes simulation results for Z1, Z3, and Z5 due to symmetric structure ----##

                                  ## ---- Sajjad Nassirpour and Alireza Vahid ---- ##
        
                       ## ---- Electrical engineering at University of Codolardo Denver ---- ##

# %% [markdown]
# # Import Packages

# %%
from scipy.stats import bernoulli
import numpy as np
import pandas as pd
from scipy.stats import poisson
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Function for finding the row of origin queues in Control Table

# %%
## ---- Calculation for finding the row in control table ---- ##

def ctrl_I_finder(number_of_packets_Q1,number_of_packets_Q2):
    if number_of_packets_Q1[0,0]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=0
            pointer_2=0
            control_num=15
        
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=0
            pointer_2=2
            control_num=12
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=0
            pointer_2=4
            control_num=13
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=0
            pointer_2=3
            control_num=14
        elif number_of_packets_Q2[0,5]!=0:
            pointer_1=0
            pointer_2=5
            control_num=21
        
    
        
    elif number_of_packets_Q1[0,2]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=2
            pointer_2=0
            control_num=9
        
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=2
            pointer_2=2
            control_num=0
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=2
            pointer_2=4
            control_num=1
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=2
            pointer_2=3
            control_num=2
        elif number_of_packets_Q2[0,5]!=0:
            pointer_1=2
            pointer_2=5
            control_num=22
        
    elif number_of_packets_Q1[0,3]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=3
            pointer_2=0
            control_num=10
        
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=3
            pointer_2=2
            control_num=3
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=3
            pointer_2=4
            control_num=4
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=3
            pointer_2=3
            control_num=5 
        elif number_of_packets_Q2[0,5]!=0:
            pointer_1=3
            pointer_2=5
            control_num=23

    elif number_of_packets_Q1[0,4]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=4
            pointer_2=0
            control_num=11
        
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=4
            pointer_2=2
            control_num=6
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=4
            pointer_2=4
            control_num=7
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=4
            pointer_2=3
            control_num=8
        elif number_of_packets_Q2[0,5]!=0:
            pointer_1=4
            pointer_2=5
            control_num=24
            
    elif number_of_packets_Q1[0,5]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=5
            pointer_2=0
            control_num=16
        
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=5
            pointer_2=2
            control_num=17
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=5
            pointer_2=4
            control_num=19
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=5
            pointer_2=3
            control_num=18
        elif number_of_packets_Q2[0,5]!=0:
            pointer_1=5
            pointer_2=5
            control_num=20
        
    return pointer_1,pointer_2,control_num

# %% [markdown]
# ## Function for finding the SN number

# %%
def case_cal(q11,q12,q21,q22):
    if q11==1 and q12==1 and q21==1 and q22==1:
        case_num=1
    elif q11==1 and q12==1 and q21==0 and q22==1:
        case_num=2
    elif q11==1 and q12==0 and q21==1 and q22==1:
        case_num=3
    elif q11==1 and q12==0 and q21==0 and q22==1:
        case_num=4
    elif q11==1 and q12==0 and q21==0 and q22==0:
        case_num=5
    elif q11==1 and q12==1 and q21==0 and q22==0:
        case_num=6
    elif q11==1 and q12==0 and q21==1 and q22==0:
        case_num=7
    elif q11==1 and q12==1 and q21==1 and q22==0:
        case_num=8
    elif q11==0 and q12==0 and q21==0 and q22==1:
        case_num=9
    elif q11==0 and q12==0 and q21==1 and q22==1:
        case_num=10
    elif q11==0 and q12==1 and q21==0 and q22==1:
        case_num=11
    elif q11==0 and q12==1 and q21==1 and q22==1:
        case_num=12
    elif q11==0 and q12==0 and q21==1 and q22==0:
        case_num=13
    elif q11==0 and q12==1 and q21==0 and q22==0:
        case_num=14
    elif q11==0 and q12==1 and q21==1 and q22==0:
        case_num=15
    elif q11==0 and q12==0 and q21==0 and q22==0:
        case_num=16
    return case_num

# %% [markdown]
# # Function for data movement when only T1 has data bit to send

# %%
def T1_select(number_of_packets_Q1,q11,q12):
    if number_of_packets_Q1[0,0]!=0:
        pointer_1=0
        if q11==1 and q12==1:
            Q_des_Q1=7
        elif q11==1 and q12==0:
            Q_des_Q1=5
        elif q11==0 and q12==1:
            Q_des_Q1=4
        elif q11==0 and q12==0:
            Q_des_Q1=1
    
    elif number_of_packets_Q1[0,2]!=0:
        pointer_1=2
        if q11==1 and q12==1:
            Q_des_Q1=7
        elif q11==1 and q12==0:
            Q_des_Q1=7
        elif q11==0 and q12==1:
            Q_des_Q1=4
        elif q11==0 and q12==0:
            Q_des_Q1=3
    elif number_of_packets_Q1[0,3]!=0:
        pointer_1=3
        if q11==1 and q12==1:
            Q_des_Q1=7
        elif q11==1 and q12==0:
            Q_des_Q1=7
        elif q11==0 and q12==1:
            Q_des_Q1=4
        elif q11==0 and q12==0:
            Q_des_Q1=4
    elif number_of_packets_Q1[0,4]!=0:
        pointer_1=4
        if q11==1 and q12==1:
            Q_des_Q1=7
        elif q11==1 and q12==0:
            Q_des_Q1=5
        elif q11==0 and q12==1:
            Q_des_Q1=7
        elif q11==0 and q12==0:
            Q_des_Q1=5
    elif number_of_packets_Q1[0,5]!=0:
        pointer_1=5
        if q11==1 and q12==1:
            Q_des_Q1=7
        elif q11==1 and q12==0:
            Q_des_Q1=5
        elif q11==0 and q12==1:
            Q_des_Q1=4
        elif q11==0 and q12==0:
            Q_des_Q1=6
    return Q_des_Q1,pointer_1

# %% [markdown]
# # Function for data movement when only T2 has data bit to send

# %%
def T2_select(number_of_packets_Q2,q22,q21):
    if number_of_packets_Q2[0,0]!=0:
        pointer_2=0
        if q22==1 and q21==1:
            Q_des_Q2=7
        elif q22==1 and q21==0:
            Q_des_Q2=4
        elif q22==0 and q21==1:
            Q_des_Q2=5
        elif q22==0 and q21==0:
            Q_des_Q2=1
    
    elif number_of_packets_Q2[0,2]!=0:
        pointer_2=2
        if q22==1 and q21==1:
            Q_des_Q2=7
        elif q22==1 and q21==0:
            Q_des_Q2=7
        elif q22==0 and q21==1:
            Q_des_Q2=5
        elif q22==0 and q21==0:
            Q_des_Q2=3
    elif number_of_packets_Q2[0,4]!=0:
        pointer_2=4
        if q22==1 and q21==1:
            Q_des_Q2=7
        elif q22==1 and q21==0:
            Q_des_Q2=7
        elif q22==0 and q21==1:
            Q_des_Q2=5
        elif q22==0 and q21==0:
            Q_des_Q2=5
    elif number_of_packets_Q2[0,3]!=0:
        pointer_2=3
        if q22==1 and q21==1:
            Q_des_Q2=7
        elif q22==1 and q21==0:
            Q_des_Q2=4
        elif q22==0 and q21==1:
            Q_des_Q2=7
        elif q22==0 and q21==0:
            Q_des_Q2=4
    
    elif number_of_packets_Q2[0,5]!=0:
        pointer_2=5
        if q22==1 and q21==1:
            Q_des_Q2=7
        elif q22==1 and q21==0:
            Q_des_Q2=4
        elif q22==0 and q21==1:
            Q_des_Q2=5
        elif q22==0 and q21==0:
            Q_des_Q2=6
            
    return Q_des_Q2,pointer_2

# %% [markdown]
# ## Read control table CSV files

# %%
## ---- Control Table for T1 ---- ##
control_I_T1=pd.read_csv('Control table for T1 - v2.csv')
control_I_T1=control_I_T1.values

## ---- Control Table for T2 ---- ##
control_I_T2=pd.read_csv('Control table for T2 - v2.csv')
control_I_T2=control_I_T2.values

# %% [markdown]
# ## Derive corner points

# %%
#====== Erasure Probability of the links =======#

erasure_probability11=0.4
erasure_probability12=0.6
erasure_probability22=0.2
erasure_probability21=0.5


p_val_d_1=1-erasure_probability11
p_val_c_1=1-erasure_probability12

p_val_d_2=1-erasure_probability22
p_val_c_2=1-erasure_probability21

print("The information-theoretic outer-bounds can be respresented as:")
print('R1 = ', np.round(p_val_d_1,2))
print('R2 = ', np.round(p_val_d_2,2))
a1=1
b1=(p_val_d_1+p_val_c_1-p_val_d_1*p_val_c_1)/p_val_c_1
c1=((p_val_d_1+p_val_c_1-p_val_d_1*p_val_c_1)*(p_val_d_2+p_val_c_1-p_val_d_2*p_val_c_1))/p_val_c_1

print('R1 +',format(b1, '.3f'),'R2 =', format(c1,'.3f'))
a2=(p_val_d_2+p_val_c_2-p_val_d_2*p_val_c_2)/p_val_c_2
b2=1
c2=(p_val_d_2+p_val_c_2-p_val_d_2*p_val_c_2)*(p_val_d_1+p_val_c_2-p_val_d_1*p_val_c_2)/p_val_c_2

print(format(a2, '.3f'),'R1 +','R2 =', format(c2, '.3f'))

#======== Finding Corner Point C ========#
detc_2=np.array([[a1, c1],[a2, c2]])
denom=np.array([[a1, b1],[a2, b2]])

lamm2=np.linalg.det(detc_2)/np.linalg.det(denom)
lamm2=np.round(lamm2,4)
detc_1=np.array([[c1, b1],[c2, b2]])
denom=np.array([[a1, b1],[a2, b2]])

lamm1=np.linalg.det(detc_1)/np.linalg.det(denom)
lamm1=np.round(lamm1,4)

point_c=np.array([lamm2, lamm1])

#======== Finding Corner Point A ========#

lamm11=c1-(b1*p_val_d_2)
lamm12=c2-(b2*p_val_d_2)
if lamm11<lamm12:
    lamm1=np.round(lamm11,4)
else: 
    lamm1=np.round(lamm12,4)
        
lamm2=p_val_d_2
point_a=np.array([lamm2, lamm1])

#======== Finding Corner Point B ========#

lamm21=c1-(a1*p_val_d_1)
lamm22=c2-(a2*p_val_d_1)
if lamm21<lamm22:
    lamm2=np.round(lamm21,4)
else: 
    lamm2=np.round(lamm22,4)
        
lamm1=p_val_d_1
point_b=np.array([lamm2, lamm1])


## ---- Print Corner Points ---- ##
print('============================================')
print("The Corner Points can be shown as follow:")

print('Corner Point A =',point_a)
print('Corner Point B =',point_b)
print('Corner Point C =',point_c)
# Out:
# The information-theoretic outer-bounds can be respresented as:
# R1 =  0.6
# R2 =  0.8
# R1 + 1.900 R2 = 1.672
# 1.800 R1 + R2 = 1.440
# ============================================
# The Corner Points can be shown as follow:
# Corner Point A = [0.8   0.152]
# Corner Point B = [0.36 0.6 ]
# Corner Point C = [0.6486 0.4397]

# %% [markdown]
# # Generate P[t]

# %%
##===== Select arriving rates =====##

lambda_1=0.4397  #Arriving rate at Tx1
lambda_2=0.6   #Arriving rate

if lambda_1<=point_c[0] and lambda_2<=point_c[1]:
    P_t=1
elif lambda_1<=point_b[0] and lambda_2>=point_c[1]:
    P_t=0
elif lambda_1<=point_c[0] and lambda_2>=point_c[1]:
    
    lam1_max=point_b[0]
    lam2_max=point_b[1]
    P_t=((lam2_max-lam1_max)-(lambda_2-lambda_1))/((lam2_max-lam1_max)-(point_c[0]-point_c[1]))
    
print('P[t]=',P_t)
# Out:
# P[t]= 0

# %% [markdown]
# # Transmission Protocol

# %%
## ---- Calculate number of iteration based on "communication_time", "erasure_probability", "reliability" and "accuracy" ---- ##
erasure_probability=erasure_probability11
beta=225  #beta
communication_time=50000
reliability=0.95
accuracy=0.0005
iters=np.round(1/(((1-reliability)/(erasure_probability*(1-erasure_probability)))*accuracy**2*communication_time))
iters=iters.astype(np.int64)


packet_num=communication_time-beta  # Time insterval when newly data bits are arriving

# ---- Initial values for errors ---- #
delta_1=0
delta_2=0

for rep in range(iters):

    print('repetition=',rep+1) # print current repetition number
    print('Communication_time=',communication_time)
    print('Number of iterations=',iters)     


    # ---- Arriving rates---- #

    print('lambda_1=',lambda_1)
    print('lambda_2=',lambda_2)

    # ---- Generate Poisson sequences with lambda values ---- #
    
    arrived_pkt_1=poisson.rvs(lambda_1, size=packet_num)
    lambda_1_r=np.sum(arrived_pkt_1)/packet_num

    arrived_pkt_2=poisson.rvs(lambda_2, size=packet_num)
    lambda_2_r=np.sum(arrived_pkt_2)/packet_num
    
    # ---- Make sure that generated sequences has expected_value=lambdas ---- #
    
    while (lambda_1-0.01)>lambda_1_r or lambda_1_r>lambda_1:
        arrived_pkt_1=poisson.rvs(lambda_1, size=packet_num)
        lambda_1_r=np.sum(arrived_pkt_1)/packet_num
        
    while (lambda_2-0.01)>lambda_2_r or lambda_2_r>lambda_2:
        arrived_pkt_2=poisson.rvs(lambda_2, size=packet_num)
        lambda_2_r=np.sum(arrived_pkt_2)/packet_num
    

    pkt_ind_1=np.zeros((1, 7))-np.ones((1, 7))
    pkt_ind_2=np.zeros((1, 7))-np.ones((1, 7))


    # ----- initial value for all of the Queues(Q1) ----- #

    Q1_total=np.zeros((7, packet_num))
    number_of_packets_Q1=np.zeros((1, 7))
    for num_pkt1 in range(6):
        number_of_packets_Q1[0,num_pkt1]=np.count_nonzero(Q1_total[num_pkt1,:])
        
    # ----- initial value for all of the Queues(Q2) ----- #
    
    Q2_total=np.zeros((7, packet_num))
    number_of_packets_Q2=np.zeros((1, 7))
    for num_pkt2 in range(6):
        number_of_packets_Q2[0,num_pkt2]=np.count_nonzero(Q2_total[num_pkt2,:])

    # ----- Bernoulli Generators for S_ij(t) ----- #

    q11=1-erasure_probability
    q12=1-erasure_probability
    q21=1-erasure_probability
    q22=1-erasure_probability



    uu=1000  # uu is used to show every proceess for packet_num on every 1000 time instants
    
    for i in range(packet_num+beta):

        if i>=uu:
            print(i)
            uu=uu+1000

        if i>packet_num-1:
            arrived_pkt_T1 =0
            arrived_pkt_T2 =0
        else:

            arrived_pkt_T1 = arrived_pkt_1[i]
            arrived_pkt_T2 = arrived_pkt_2[i]
    
        # ---- New arrived data bits join initial queues ---- #

        if arrived_pkt_T1!=0:
            for p in range(arrived_pkt_T1):
                Q_des_Q1=3
                pkt_ind_1[0,(Q_des_Q1-1)]=pkt_ind_1[0,(Q_des_Q1-1)]+1
                b1=pkt_ind_1[0,(Q_des_Q1-1)]
                b1=b1.astype(np.int64)
                Q1_total[(Q_des_Q1-1),b1]=1

        if arrived_pkt_T2!=0:
            for p in range(arrived_pkt_T2):
                Q_des_Q2=3
                pkt_ind_2[0,(Q_des_Q2-1)]=pkt_ind_2[0,(Q_des_Q2-1)]+1
                b2=pkt_ind_2[0,(Q_des_Q2-1)]
                b2=b2.astype(np.int64)
                Q2_total[(Q_des_Q2-1),b2]=1

        for num_pkt1 in range(6):
            number_of_packets_Q1[0,num_pkt1]=np.count_nonzero(Q1_total[num_pkt1,:])

        for num_pkt2 in range(6):
            number_of_packets_Q2[0,num_pkt2]=np.count_nonzero(Q2_total[num_pkt2,:])

        if np.sum(number_of_packets_Q1)==0 or np.sum(number_of_packets_Q2)==0:
            
            if np.sum(number_of_packets_Q1)!=0:
                data_q11= bernoulli.rvs(size=1,p=q11)
                data_q12= bernoulli.rvs(size=1,p=q12)
                Q_des_Q1,pointer_1=T1_select(number_of_packets_Q1,data_q11,data_q12)
                
                ## ----- Data movement from origin queue ----- ##
                
                a1=pkt_ind_1[0,(pointer_1)]
                a1=a1.astype(np.int64)
                val=Q1_total[(pointer_1),a1]
                Q1_total[(pointer_1),a1]=0
                pkt_ind_1[0,(pointer_1)]=pkt_ind_1[0,(pointer_1)]-1

                ## ----- Data movement in destination queue ----- ##

                pkt_ind_1[0,(Q_des_Q1-1)]=pkt_ind_1[0,(Q_des_Q1-1)]+1
                b1=pkt_ind_1[0,(Q_des_Q1-1)]
                b1=b1.astype(np.int64)
                Q1_total[(Q_des_Q1-1),b1]=val

            if np.sum(number_of_packets_Q2)!=0:
                data_q22= bernoulli.rvs(size=1,p=q22)
                data_q21= bernoulli.rvs(size=1,p=q21)
                Q_des_Q2,pointer_2=T2_select(number_of_packets_Q2,data_q22,data_q21)
                
                ## ----- Data movement from origin queue ----- ##
                
                a2=pkt_ind_2[0,(pointer_2)]
                a2=a2.astype(np.int64)
                val=Q2_total[(pointer_2),a2]
                Q2_total[(pointer_2),a2]=0
                pkt_ind_2[0,(pointer_2)]=pkt_ind_2[0,(pointer_2)]-1

                ## ----- Data movement in destination queue ----- ##

                pkt_ind_2[0,(Q_des_Q2-1)]=pkt_ind_2[0,(Q_des_Q2-1)]+1
                b2=pkt_ind_2[0,(Q_des_Q2-1)]
                b2=b2.astype(np.int64)
                Q2_total[(Q_des_Q2-1),b2]=val

        else:

            pointer_1,pointer_2,control_num=ctrl_I_finder(number_of_packets_Q1,number_of_packets_Q2)

            data_q11= bernoulli.rvs(size=1,p=q11)
            data_q12= bernoulli.rvs(size=1,p=q12)
            data_q21= bernoulli.rvs(size=1,p=q21)
            data_q22= bernoulli.rvs(size=1,p=q22)
            case_num=case_cal(data_q11,data_q12,data_q21,data_q22)
            
            ## ----- Data movement from origin queue ----- ##
                
            a1=pkt_ind_1[0,(pointer_1)]
            a1=a1.astype(np.int64)
            val_1=Q1_total[(pointer_1),a1]
            Q1_total[(pointer_1),a1]=0
            pkt_ind_1[0,(pointer_1)]=pkt_ind_1[0,(pointer_1)]-1
            
            a2=pkt_ind_2[0,(pointer_2)]
            a2=a2.astype(np.int64)
            val_2=Q2_total[(pointer_2),a2]
            Q2_total[(pointer_2),a2]=0
            pkt_ind_2[0,(pointer_2)]=pkt_ind_2[0,(pointer_2)]-1

                    
            Q_des_Q1=control_I_T1[control_num,case_num]
            Q_des_Q2=control_I_T2[control_num,case_num] 
            
            
            if control_num==12 or control_num==15:
                if case_num==7:
                    Q_des_Q2=5

                if case_num==12:
                    Q_des_Q1=5
                    Q_des_Q2=4
                    
            
            if control_num==9 or control_num==15:
                if case_num==11:
                    Q_des_Q1=4
                if case_num==8:
                    Q_des_Q1=5
                    Q_des_Q2=4
            
            #== Flexible destination Queues ==#          
                    
            if Q_des_Q1==11 and Q_des_Q2==11:
                
                if bernoulli.rvs(size=1,p=P_t)==1:
                    Q_des_Q1=6
                    Q_des_Q2=6
                else:
                    Q_des_Q1=1
                    Q_des_Q2=7
                
                    
            if Q_des_Q1==12 and Q_des_Q2==12:

                if bernoulli.rvs(size=1,p=0)==1:
                    Q_des_Q1=7
                    Q_des_Q2=5
                else:
                    Q_des_Q1=5
                    Q_des_Q2=7
                    
            if Q_des_Q1==13 and Q_des_Q2==13:

                if bernoulli.rvs(size=1,p=P_t)==1:
                    Q_des_Q1=6
                    Q_des_Q2=6
                else:
                    Q_des_Q1=1
                    Q_des_Q2=7
                    
            if Q_des_Q1==14 and Q_des_Q2==14:

                if bernoulli.rvs(size=1,p=P_t)==1:
                    Q_des_Q1=7
                    Q_des_Q2=4
                else:
                    Q_des_Q1=4
                    Q_des_Q2=7
                    
                    
            if Q_des_Q1==15 and Q_des_Q2==15:

                if bernoulli.rvs(size=1,p=0)==1:
                    Q_des_Q1=7
                    Q_des_Q2=5
                else:
                    Q_des_Q1=5
                    Q_des_Q2=7
                    
            if Q_des_Q1==16 and Q_des_Q2==16:

                if bernoulli.rvs(size=1,p=P_t)==1:
                    Q_des_Q1=7
                    Q_des_Q2=4
                else:
                    Q_des_Q1=4
                    Q_des_Q2=7
                    
            if Q_des_Q1==17 and Q_des_Q2==17:

                if bernoulli.rvs(size=1,p=P_t)==1:
                    Q_des_Q1=7
                    Q_des_Q2=4
                else:
                    Q_des_Q1=4
                    Q_des_Q2=7
                    
            if Q_des_Q1==18 and Q_des_Q2==18:

                if bernoulli.rvs(size=1,p=0)==1:
                    Q_des_Q1=7
                    Q_des_Q2=5
                else:
                    Q_des_Q1=5
                    Q_des_Q2=7

            ## ----- Data movement in destination queue ----- ##
            
            pkt_ind_1[0,(Q_des_Q1-1)]=pkt_ind_1[0,(Q_des_Q1-1)]+1
            b1=pkt_ind_1[0,(Q_des_Q1-1)]
            b1=b1.astype(np.int64)
            Q1_total[(Q_des_Q1-1),b1]=val_1

            pkt_ind_2[0,(Q_des_Q2-1)]=pkt_ind_2[0,(Q_des_Q2-1)]+1
            b2=pkt_ind_2[0,(Q_des_Q2-1)]
            b2=b2.astype(np.int64)
            Q2_total[(Q_des_Q2-1),b2]=val_2

        number_of_packets_Q1_c1=np.count_nonzero(Q1_total[5,:]) 
        number_of_packets_Q2_c1=np.count_nonzero(Q2_total[5,:])
         ## --------- ##
        number_of_packets_Q1_1_2=np.count_nonzero(Q1_total[3,:]) 
        number_of_packets_Q2_1_2=np.count_nonzero(Q2_total[3,:])
         ## --------- ##
        number_of_packets_Q1_2_1=np.count_nonzero(Q1_total[4,:]) 
        number_of_packets_Q2_2_1=np.count_nonzero(Q2_total[4,:])

           
    ##### ---------------- XOR Combination procedure for Q1 ---------------- #####
          # ---- Q1_2_1 & Q1_1_2 -- Q1_c1 & Q1_2_1 -- Q1_c1 & Q1_1_2 ---- #
        
        if number_of_packets_Q1_2_1!=0: 
            if number_of_packets_Q1_1_2!=0:
                pack=[4,3]
                pack=np.asarray(pack)
                val=0
                for jj in range(len(pack)):
                    
                    ## ----- Data movement from origin queue ----- ##
                    
                    Q_des_Q1=pack[jj]
                    b1=pkt_ind_1[0,(Q_des_Q1)]
                    b1=b1.astype(np.int64)
                    val=Q1_total[(Q_des_Q1),b1]+val
                    Q1_total[(Q_des_Q1),b1]=0
                    pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]-1
                    
                    ## ----- Data movement in destination queue ----- ##
                    
                Q_des_Q1=0
                pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]+1
                b1=pkt_ind_1[0,(Q_des_Q1)]
                b1=b1.astype(np.int64)
                Q1_total[(Q_des_Q1),b1]=val

        if number_of_packets_Q1_c1!=0: 
            if number_of_packets_Q1_1_2!=0:

                pack=[5,3]
                pack=np.asarray(pack)
                val=0
                for jj in range(len(pack)):
                    
                    ## ----- Data movement from origin queue ----- ##
                    
                    Q_des_Q1=pack[jj]
                    b1=pkt_ind_1[0,(Q_des_Q1)]
                    b1=b1.astype(np.int64)
                    val=Q1_total[(Q_des_Q1),b1]+val
                    Q1_total[(Q_des_Q1),b1]=0
                    pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]-1
                    
                    ## ----- Data movement in destination queue ----- ##
                    
                Q_des_Q1=0
                pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]+1
                b1=pkt_ind_1[0,(Q_des_Q1)]
                b1=b1.astype(np.int64)
                Q1_total[(Q_des_Q1),b1]=val

        if number_of_packets_Q1_2_1!=0: 
            if number_of_packets_Q1_c1!=0:
                pack=[4,5]
                pack=np.asarray(pack)
                val=0
                for jj in range(len(pack)):
                    
                    ## ----- Data movement from origin queue ----- ##
                    
                    Q_des_Q1=pack[jj]
                    b1=pkt_ind_1[0,(Q_des_Q1)]
                    b1=b1.astype(np.int64)
                    val=Q1_total[(Q_des_Q1),b1]+val
                    Q1_total[(Q_des_Q1),b1]=0
                    pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]-1
                    
                    ## ----- Data movement in destination queue ----- ##
                    
                Q_des_Q1=0
                pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]+1
                b1=pkt_ind_1[0,(Q_des_Q1)]
                b1=b1.astype(np.int64)
                Q1_total[(Q_des_Q1),b1]=val


       ##### ---------------- XOR Combination procedure for Q2 ---------------- #####
             # ---- Q2_2_1 & Q2_1_2 -- Q2_c1 & Q2_1_2 -- Q2_c1 & Q2_1_2 ---- #
        
        if number_of_packets_Q2_1_2!=0: 
            if number_of_packets_Q2_2_1!=0:
                pack=[3,4]
                pack=np.asarray(pack)
                val=0
                for jj in range(len(pack)):
                    
                    ## ----- Data movement from origin queue ----- ##
                    
                    Q_des_Q2=pack[jj]
                    b1=pkt_ind_2[0,(Q_des_Q2)]
                    b1=b1.astype(np.int64)
                    val=Q2_total[(Q_des_Q2),b1]+val
                    Q2_total[(Q_des_Q2),b1]=0
                    pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]-1
                    
                    ## ----- Data movement in destination queue ----- ##
                    
                Q_des_Q2=0
                pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]+1
                b1=pkt_ind_2[0,(Q_des_Q2)]
                b1=b1.astype(np.int64)
                Q2_total[(Q_des_Q2),b1]=val
                
        if number_of_packets_Q2_c1!=0: 
            if number_of_packets_Q2_2_1!=0:
                pack=[5,4]
                pack=np.asarray(pack)
                val=0
                for jj in range(len(pack)):
                    
                    ## ----- Data movement from origin queue ----- ##
                    
                    Q_des_Q2=pack[jj]
                    b1=pkt_ind_2[0,(Q_des_Q2)]
                    b1=b1.astype(np.int64)
                    val=Q2_total[(Q_des_Q2),b1]+val
                    Q2_total[(Q_des_Q2),b1]=0
                    pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]-1
                    
                    ## ----- Data movement in destination queue ----- ##
                    
                Q_des_Q2=0
                pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]+1
                b1=pkt_ind_2[0,(Q_des_Q2)]
                b1=b1.astype(np.int64)
                Q2_total[(Q_des_Q2),b1]=val

        if number_of_packets_Q2_1_2!=0: 
            if number_of_packets_Q2_c1!=0:
                pack=[3,5]
                pack=np.asarray(pack)
                val=0
                for jj in range(len(pack)):
                    
                    ## ----- Data movement from origin queue ----- ##
                    
                    Q_des_Q2=pack[jj]
                    b1=pkt_ind_2[0,(Q_des_Q2)]
                    b1=b1.astype(np.int64)
                    val=Q2_total[(Q_des_Q2),b1]+val
                    Q2_total[(Q_des_Q2),b1]=0
                    pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]-1
                    
                    ## ----- Data movement in destination queue ----- ##
                    
                Q_des_Q2=0
                pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]+1
                b1=pkt_ind_2[0,(Q_des_Q2)]
                b1=b1.astype(np.int64)
                Q2_total[(Q_des_Q2),b1]=val

##### ---------------- Error calculations ---------------- #####

    number_of_packets_Q1_F=np.sum(Q1_total[6,:]) 
    number_of_packets_Q2_F=np.sum(Q2_total[6,:])
    

    stable_rate_T1=number_of_packets_Q1_F/packet_num
    stable_rate_T2=number_of_packets_Q2_F/packet_num

    delta_1=delta_1+((lambda_1_r-stable_rate_T1)/lambda_1_r)
    if lambda_1_r==0:
        delta_1=0
    print('delta_1=',delta_1/(rep+1))
    
    delta_2=delta_2+((lambda_2_r-stable_rate_T2)/lambda_2_r)
    if lambda_2_r==0:
        delta_2=0
    print('delta_2=',delta_2/(rep+1))
    print('-------------------------------------')
    
    
# ---------------- Final Errors ---------------- #  

delta_1=delta_1/(rep+1)
delta_2=delta_2/(rep+1)
print('Total error at Transmitter 1=',delta_1)
print('Total error at Transmitter 2=',delta_2)
# Out:
# repetition= 1
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.01025709784466875
# -------------------------------------
# repetition= 2
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008925847127858948
# -------------------------------------
# repetition= 3
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008618402115137095
# -------------------------------------
# repetition= 4
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00900200021924387
# -------------------------------------
# repetition= 5
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.010405675652152146
# -------------------------------------
# repetition= 6
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.010768782195109504
# -------------------------------------
# repetition= 7
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.010426763062204289
# -------------------------------------
# repetition= 8
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009220219026230094
# -------------------------------------
# repetition= 9
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009670245960518584
# -------------------------------------
# repetition= 10
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00922277198691537
# -------------------------------------
# repetition= 11
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008980072710611724
# -------------------------------------
# repetition= 12
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00913094357687692
# -------------------------------------
# repetition= 13
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009019346566829107
# -------------------------------------
# repetition= 14
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009273761467683722
# -------------------------------------
# repetition= 15
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008796715652068732
# -------------------------------------
# repetition= 16
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008246920923814436
# -------------------------------------
# repetition= 17
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008255889858588716
# -------------------------------------
# repetition= 18
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00807902879655862
# -------------------------------------
# repetition= 19
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008124844158903013
# -------------------------------------
# repetition= 20
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008267458640254317
# -------------------------------------
# repetition= 21
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008515001810100542
# -------------------------------------
# repetition= 22
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008707364118460018
# -------------------------------------
# repetition= 23
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008865135608786484
# -------------------------------------
# repetition= 24
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008726649816786095
# -------------------------------------
# repetition= 25
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00837758382411465
# -------------------------------------
# repetition= 26
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008641417753922909
# -------------------------------------
# repetition= 27
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008661533202447589
# -------------------------------------
# repetition= 28
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008819751355589924
# -------------------------------------
# repetition= 29
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008912734079043744
# -------------------------------------
# repetition= 30
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009172780217680658
# -------------------------------------
# repetition= 31
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009245510503684181
# -------------------------------------
# repetition= 32
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009401998790751922
# -------------------------------------
# repetition= 33
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009312632581757322
# -------------------------------------
# repetition= 34
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00903873162347034
# -------------------------------------
# repetition= 35
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009226955727359838
# -------------------------------------
# repetition= 36
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.009025237581884822
# -------------------------------------
# repetition= 37
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00906404258323983
# -------------------------------------
# repetition= 38
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008825515146838782
# -------------------------------------
# repetition= 39
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00874913717367749
# -------------------------------------
# repetition= 40
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00881095737276448
# -------------------------------------
# repetition= 41
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.00881803119247571
# -------------------------------------
# repetition= 42
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 0.0
# delta_2= 0.008647378300155266
# -------------------------------------
# repetition= 43
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 8.345886938268747e-06
# delta_2= 0.008565308156526546
# -------------------------------------
# repetition= 44
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 8.15620768967173e-06
# delta_2= 0.008370642062060034
# -------------------------------------
# repetition= 45
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.974958629901246e-06
# delta_2= 0.008305742045124466
# -------------------------------------
# repetition= 46
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.801589964033828e-06
# delta_2= 0.008370412886188736
# -------------------------------------
# repetition= 47
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.63559868820332e-06
# delta_2= 0.00837932520402763
# -------------------------------------
# repetition= 48
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.476523715532419e-06
# delta_2= 0.00840457930185047
# -------------------------------------
# repetition= 49
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.3239415988889e-06
# delta_2= 0.008322434085162493
# -------------------------------------
# repetition= 50
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.177462766911122e-06
# delta_2= 0.008389184328190429
# -------------------------------------
# repetition= 51
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 7.036728202854041e-06
# delta_2= 0.008495590089415991
# -------------------------------------
# repetition= 52
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.90140650664531e-06
# delta_2= 0.008398566731581795
# -------------------------------------
# repetition= 53
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.771191289538794e-06
# delta_2= 0.008457237853981293
# -------------------------------------
# repetition= 54
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.645798858251039e-06
# delta_2= 0.00832180130919275
# -------------------------------------
# repetition= 55
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.524966151737384e-06
# delta_2= 0.008358759117356597
# -------------------------------------
# repetition= 56
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.408448899027788e-06
# delta_2= 0.00836587437948962
# -------------------------------------
# repetition= 57
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.296019970974669e-06
# delta_2= 0.008428548450820307
# -------------------------------------
# repetition= 58
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.187467902509588e-06
# delta_2= 0.008283228649944095
# -------------------------------------
# repetition= 59
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 6.082595565178917e-06
# delta_2= 0.008211738567774
# -------------------------------------
# repetition= 60
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.981218972425935e-06
# delta_2= 0.008333408376599316
# -------------------------------------
# repetition= 61
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.8831662023861656e-06
# delta_2= 0.008366944419481588
# -------------------------------------
# repetition= 62
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.7882764249283246e-06
# delta_2= 0.008338312742608546
# -------------------------------------
# repetition= 63
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.696399021358033e-06
# delta_2= 0.008378085884485503
# -------------------------------------
# repetition= 64
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.607392786649314e-06
# delta_2= 0.008338030475513562
# -------------------------------------
# repetition= 65
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.521125205316248e-06
# delta_2= 0.00834455634055323
# -------------------------------------
# repetition= 66
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.437471793114486e-06
# delta_2= 0.008397230387917771
# -------------------------------------
# repetition= 67
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.356315497694867e-06
# delta_2= 0.008406049086837088
# -------------------------------------
# repetition= 68
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.277546152140531e-06
# delta_2= 0.008432136659751762
# -------------------------------------
# repetition= 69
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.201059976022552e-06
# delta_2= 0.008309931780624924
# -------------------------------------
# repetition= 70
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.12675911922223e-06
# delta_2= 0.008197946359943083
# -------------------------------------
# repetition= 71
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 5.054551244303607e-06
# delta_2= 0.008206347019002724
# -------------------------------------
# repetition= 72
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.9843491436882794e-06
# delta_2= 0.008362708776842436
# -------------------------------------
# repetition= 73
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.916070388295289e-06
# delta_2= 0.008382599875593862
# -------------------------------------
# repetition= 74
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.849637004669677e-06
# delta_2= 0.008540598852318417
# -------------------------------------
# repetition= 75
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.784975177940748e-06
# delta_2= 0.008432561715968935
# -------------------------------------
# repetition= 76
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.722014978231001e-06
# delta_2= 0.008436482394316852
# -------------------------------------
# repetition= 77
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.660690108383845e-06
# delta_2= 0.008421092824876197
# -------------------------------------
# repetition= 78
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.600937671096873e-06
# delta_2= 0.008405559761264374
# -------------------------------------
# repetition= 79
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.542697953741217e-06
# delta_2= 0.00841724709416486
# -------------------------------------
# repetition= 80
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.485914229319451e-06
# delta_2= 0.00831581352659988
# -------------------------------------
# repetition= 81
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.4305325721673595e-06
# delta_2= 0.008213149162073956
# -------------------------------------
# repetition= 82
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.376501687140928e-06
# delta_2= 0.008202220403141697
# -------------------------------------
# repetition= 83
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.323772751151278e-06
# delta_2= 0.008240286808858324
# -------------------------------------
# repetition= 84
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.272299266018525e-06
# delta_2= 0.008365903408727506
# -------------------------------------
# repetition= 85
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.222036921712425e-06
# delta_2= 0.00836131479584451
# -------------------------------------
# repetition= 86
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.172943469134374e-06
# delta_2= 0.008264090205195156
# -------------------------------------
# repetition= 87
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.124978601673058e-06
# delta_2= 0.008211173047952701
# -------------------------------------
# repetition= 88
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.078103844835865e-06
# delta_2= 0.008303947519020381
# -------------------------------------
# repetition= 89
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 4.032282453320855e-06
# delta_2= 0.008417272590211107
# -------------------------------------
# repetition= 90
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.987479314950623e-06
# delta_2= 0.008391837922131494
# -------------------------------------
# repetition= 91
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.943660860940177e-06
# delta_2= 0.008409391760190753
# -------------------------------------
# repetition= 92
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.900794982016914e-06
# delta_2= 0.00838915227618625
# -------------------------------------
# repetition= 93
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.858850949952216e-06
# delta_2= 0.008388784516712745
# -------------------------------------
# repetition= 94
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.81779934410166e-06
# delta_2= 0.008423052331036547
# -------------------------------------
# repetition= 95
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.777611982584801e-06
# delta_2= 0.00841811382623594
# -------------------------------------
# repetition= 96
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.7382618577662094e-06
# delta_2= 0.008444203647995335
# -------------------------------------
# repetition= 97
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.6997230757273826e-06
# delta_2= 0.008419222753484942
# -------------------------------------
# repetition= 98
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.66197079944445e-06
# delta_2= 0.008505277776441042
# -------------------------------------
# repetition= 99
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.6249811954096574e-06
# delta_2= 0.008549834859777382
# -------------------------------------
# repetition= 100
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.588731383455561e-06
# delta_2= 0.008502261473931877
# -------------------------------------
# repetition= 101
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 3.5531993895599616e-06
# delta_2= 0.008531086697460478
# -------------------------------------
# repetition= 102
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# ...
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.901009798678395e-06
# delta_2= 0.008144053191397506
# -------------------------------------
# repetition= 310
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.869071057392334e-06
# delta_2= 0.008133544925905033
# -------------------------------------
# repetition= 311
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.837337709940911e-06
# delta_2= 0.008111735468677743
# -------------------------------------
# repetition= 312
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.805807781383409e-06
# delta_2= 0.008120413626451354
# -------------------------------------
# repetition= 313
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.774479322017968e-06
# delta_2= 0.008138192832335724
# -------------------------------------
# repetition= 314
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.743350406979694e-06
# delta_2= 0.008152401427486472
# -------------------------------------
# repetition= 315
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.712419135846425e-06
# delta_2= 0.008163865294843904
# -------------------------------------
# repetition= 316
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.681683632251974e-06
# delta_2= 0.008144449040730356
# -------------------------------------
# repetition= 317
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.651142043506698e-06
# delta_2= 0.00813663634650776
# -------------------------------------
# repetition= 318
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.620792540225231e-06
# delta_2= 0.008111049439757734
# -------------------------------------
# repetition= 319
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.590633315961202e-06
# delta_2= 0.008132200672879605
# -------------------------------------
# repetition= 320
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.560662586848825e-06
# delta_2= 0.008123399260610488
# -------------------------------------
# repetition= 321
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.530878591251164e-06
# delta_2= 0.008119247951446678
# -------------------------------------
# repetition= 322
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.50127958941498e-06
# delta_2= 0.008120393839322768
# -------------------------------------
# repetition= 323
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.471863863131962e-06
# delta_2= 0.008118597129450017
# -------------------------------------
# repetition= 324
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.442629715406246e-06
# delta_2= 0.008124082965627607
# -------------------------------------
# repetition= 325
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.413575470128072e-06
# delta_2= 0.008138721428383485
# -------------------------------------
# repetition= 326
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.384699471753447e-06
# delta_2= 0.008166415819826826
# -------------------------------------
# repetition= 327
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.356000084989675e-06
# delta_2= 0.008177377488011143
# -------------------------------------
# repetition= 328
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.327475694486657e-06
# delta_2= 0.008181023974827522
# -------------------------------------
# repetition= 329
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.29912470453381e-06
# delta_2= 0.008161662713125089
# -------------------------------------
# repetition= 330
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.270945538762497e-06
# delta_2= 0.008169075682264474
# -------------------------------------
# repetition= 331
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.242936639853848e-06
# delta_2= 0.008162483359714938
# -------------------------------------
# repetition= 332
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.215096469251879e-06
# delta_2= 0.008160929628305082
# -------------------------------------
# repetition= 333
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.187423506881754e-06
# delta_2= 0.008157256948748923
# -------------------------------------
# repetition= 334
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.159916250873125e-06
# delta_2= 0.008148895781210093
# -------------------------------------
# repetition= 335
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.13257321728843e-06
# delta_2= 0.008124570719176629
# -------------------------------------
# repetition= 336
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.105392939856023e-06
# delta_2= 0.00810039044917908
# -------------------------------------
# repetition= 337
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.078373969708082e-06
# delta_2= 0.00810701068574057
# -------------------------------------
# repetition= 338
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 9.051514875123146e-06
# delta_2= 0.00813297227301876
# -------------------------------------
# repetition= 339
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# delta_1= 1.0095800265976474e-05
# delta_2= 0.008129870547871154
# -------------------------------------
# repetition= 340
# Communication_time= 50000
# Number of iterations= 384
# lambda_1= 0.336
# lambda_2= 0.6
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-c4e847eaab57> in <module>
#     289
#     290         number_of_packets_Q1_c1=np.count_nonzero(Q1_total[5,:])
# --> 291         number_of_packets_Q2_c1=np.count_nonzero(Q2_total[5,:])
#     292          ## --------- ##
#     293         number_of_packets_Q1_1_2=np.count_nonzero(Q1_total[3,:])
#
# <__array_function__ internals> in count_nonzero(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\core\numeric.py in count_nonzero(a, axis)
#     450     """
#     451     if axis is None:
# --> 452         return multiarray.count_nonzero(a)
#     453
#     454     a = asanyarray(a)
#
# KeyboardInterrupt:

# %%
print(Q_des_Q1)

# %%
print(Q_des_Q2)
