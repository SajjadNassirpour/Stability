# %% [markdown]
# # Code Description

# %%
              
                 ##-----****---"On the Stability Region of Intermittent Interference Networks"---****-----##
        
                    #- This code simulates the results of "non-symmetric non-homogeneous settings" -#
            
                        ##---- This code describes simulation results for cornerpoint C ----##

                                  ## ---- Sajjad Nassirpour and Alireza Vahid ---- ##
        
                       ## ---- Electrical engineering at University of Codolardo Denver ---- ##

# %% [markdown]
# # Import Packages

# %%
from scipy.stats import bernoulli
import numpy as np
import pandas as pd
from scipy.stats import poisson
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Function for finding the row of origin queues in Control Table

# %%
## ---- Calculation for finding the row in control table ---- ##

def ctrl_I_finder(number_of_packets_Q1,number_of_packets_Q2):
    if number_of_packets_Q1[0,0]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=0
            pointer_2=0
            control_num=15
        elif number_of_packets_Q2[0,1]!=0:
            pointer_1=0
            pointer_2=1
            control_num=12
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=0
            pointer_2=3
            control_num=13
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=0
            pointer_2=2
            control_num=14
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=0
            pointer_2=4
            control_num=21

        
    elif number_of_packets_Q1[0,1]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=1
            pointer_2=0
            control_num=9
        elif number_of_packets_Q2[0,1]!=0:
            pointer_1=1
            pointer_2=1
            control_num=0
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=1
            pointer_2=3
            control_num=1
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=1
            pointer_2=2
            control_num=2
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=1
            pointer_2=4
            control_num=22

            
    elif number_of_packets_Q1[0,2]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=2
            pointer_2=0
            control_num=10
        elif number_of_packets_Q2[0,1]!=0:
            pointer_1=2
            pointer_2=1
            control_num=3
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=2
            pointer_2=3
            control_num=4
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=2
            pointer_2=2
            control_num=5
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=2
            pointer_2=4
            control_num=23
            
            
    elif number_of_packets_Q1[0,3]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=3
            pointer_2=0
            control_num=11
        elif number_of_packets_Q2[0,1]!=0:
            pointer_1=3
            pointer_2=1
            control_num=6
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=3
            pointer_2=3
            control_num=7
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=3
            pointer_2=2
            control_num=8
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=3
            pointer_2=4
            control_num=24 
            
            
    elif number_of_packets_Q1[0,4]!=0:
        if number_of_packets_Q2[0,0]!=0:
            pointer_1=4
            pointer_2=0
            control_num=16
        elif number_of_packets_Q2[0,1]!=0:
            pointer_1=4
            pointer_2=1
            control_num=17
        elif number_of_packets_Q2[0,3]!=0:
            pointer_1=4
            pointer_2=3
            control_num=19
        elif number_of_packets_Q2[0,2]!=0:
            pointer_1=4
            pointer_2=2
            control_num=18
        elif number_of_packets_Q2[0,4]!=0:
            pointer_1=4
            pointer_2=4
            control_num=20
          
      
    return pointer_1,pointer_2,control_num

# %% [markdown]
# ## Function for finding the SN number

# %%
def case_cal(q11,q12,q21,q22):
    if q11==1 and q12==1 and q21==1 and q22==1:
        case_num=1
    elif q11==1 and q12==1 and q21==0 and q22==1:
        case_num=2
    elif q11==1 and q12==0 and q21==1 and q22==1:
        case_num=3
    elif q11==1 and q12==0 and q21==0 and q22==1:
        case_num=4
    elif q11==1 and q12==0 and q21==0 and q22==0:
        case_num=5
    elif q11==1 and q12==1 and q21==0 and q22==0:
        case_num=6
    elif q11==1 and q12==0 and q21==1 and q22==0:
        case_num=7
    elif q11==1 and q12==1 and q21==1 and q22==0:
        case_num=8
    elif q11==0 and q12==0 and q21==0 and q22==1:
        case_num=9
    elif q11==0 and q12==0 and q21==1 and q22==1:
        case_num=10
    elif q11==0 and q12==1 and q21==0 and q22==1:
        case_num=11
    elif q11==0 and q12==1 and q21==1 and q22==1:
        case_num=12
    elif q11==0 and q12==0 and q21==1 and q22==0:
        case_num=13
    elif q11==0 and q12==1 and q21==0 and q22==0:
        case_num=14
    elif q11==0 and q12==1 and q21==1 and q22==0:
        case_num=15
    elif q11==0 and q12==0 and q21==0 and q22==0:
        case_num=16
    return case_num

# %% [markdown]
# # Function for data movement when only T1 has data bits to send

# %%
def T1_select(number_of_packets_Q1,q11,q12):
    if number_of_packets_Q1[0,0]!=0:
        pointer_1=0
        if q11==1 and q12==1:
            Q_des_Q1=6
        elif q11==1 and q12==0:
            Q_des_Q1=4
        elif q11==0 and q12==1:
            Q_des_Q1=3
        elif q11==0 and q12==0:
            Q_des_Q1=1

    elif number_of_packets_Q1[0,1]!=0:
        pointer_1=1
        if q11==1 and q12==1:
            Q_des_Q1=6
        elif q11==1 and q12==0:
            Q_des_Q1=6
        elif q11==0 and q12==1:
            Q_des_Q1=3
        elif q11==0 and q12==0:
            Q_des_Q1=2
    elif number_of_packets_Q1[0,2]!=0:
        pointer_1=2
        if q11==1 and q12==1:
            Q_des_Q1=6
        elif q11==1 and q12==0:
            Q_des_Q1=6
        elif q11==0 and q12==1:
            Q_des_Q1=3
        elif q11==0 and q12==0:
            Q_des_Q1=3
    elif number_of_packets_Q1[0,3]!=0:
        pointer_1=3
        if q11==1 and q12==1:
            Q_des_Q1=6
        elif q11==1 and q12==0:
            Q_des_Q1=4
        elif q11==0 and q12==1:
            Q_des_Q1=6
        elif q11==0 and q12==0:
            Q_des_Q1=4
    elif number_of_packets_Q1[0,4]!=0:
        pointer_1=4
        if q11==1 and q12==1:
            Q_des_Q1=6
        elif q11==1 and q12==0:
            Q_des_Q1=4
        elif q11==0 and q12==1:
            Q_des_Q1=3
        elif q11==0 and q12==0:
            Q_des_Q1=5
    return Q_des_Q1,pointer_1

# %% [markdown]
# # Function for data movement when only T2 has data bits to send

# %%
def T2_select(number_of_packets_Q2,q22,q21):
    if number_of_packets_Q2[0,0]!=0:
        pointer_2=0
        if q22==1 and q21==1:
            Q_des_Q2=6
        elif q22==1 and q21==0:
            Q_des_Q2=3
        elif q22==0 and q21==1:
            Q_des_Q2=4
        elif q22==0 and q21==0:
            Q_des_Q2=1

    elif number_of_packets_Q2[0,1]!=0:
        pointer_2=1
        if q22==1 and q21==1:
            Q_des_Q2=6
        elif q22==1 and q21==0:
            Q_des_Q2=6
        elif q22==0 and q21==1:
            Q_des_Q2=4
        elif q22==0 and q21==0:
            Q_des_Q2=2
            
    elif number_of_packets_Q2[0,3]!=0:
        pointer_2=3
        if q22==1 and q21==1:
            Q_des_Q2=6
        elif q22==1 and q21==0:
            Q_des_Q2=6
        elif q22==0 and q21==1:
            Q_des_Q2=4
        elif q22==0 and q21==0:
            Q_des_Q2=4
    
    elif number_of_packets_Q2[0,2]!=0:
        pointer_2=2
        if q22==1 and q21==1:
            Q_des_Q2=6
        elif q22==1 and q21==0:
            Q_des_Q2=3
        elif q22==0 and q21==1:
            Q_des_Q2=6
        elif q22==0 and q21==0:
            Q_des_Q2=3
    
    elif number_of_packets_Q2[0,4]!=0:
        pointer_2=4
        if q22==1 and q21==1:
            Q_des_Q2=6
        elif q22==1 and q21==0:
            Q_des_Q2=6
        elif q22==0 and q21==1:
            Q_des_Q2=5
        elif q22==0 and q21==0:
            Q_des_Q2=5
            
    return Q_des_Q2,pointer_2

# %% [markdown]
# ## Read control table CSV files

# %%
## ---- Control Table for T1 ---- ##
control_I_T1=pd.read_csv('Control table for T1_ordinary_procedure_v2.csv')
control_I_T1=control_I_T1.values

## ---- Control Table for T2 ---- ##
control_I_T2=pd.read_csv('Control table for T2_ordinary_procedure_v2.csv')
control_I_T2=control_I_T2.values

# %% [markdown]
# ## Derive Coner Points

# %%
#====== Erasure Probability of the links =======#

erasure_probability11=0.4
erasure_probability12=0.6
erasure_probability22=0.2
erasure_probability21=0.5


p_val_d_1=1-erasure_probability11
p_val_c_1=1-erasure_probability12

p_val_d_2=1-erasure_probability22
p_val_c_2=1-erasure_probability21

print("The information-theoretic outer-bounds can be respresented as:")
print('R1 = ', np.round(p_val_d_1,2))
print('R2 = ', np.round(p_val_d_2,2))
a1=1
b1=(p_val_d_1+p_val_c_1-p_val_d_1*p_val_c_1)/p_val_c_1
c1=((p_val_d_1+p_val_c_1-p_val_d_1*p_val_c_1)*(p_val_d_2+p_val_c_1-p_val_d_2*p_val_c_1))/p_val_c_1

print('R1 +',format(b1, '.3f'),'R2 =', format(c1,'.3f'))
a2=(p_val_d_2+p_val_c_2-p_val_d_2*p_val_c_2)/p_val_c_2
b2=1
c2=(p_val_d_2+p_val_c_2-p_val_d_2*p_val_c_2)*(p_val_d_1+p_val_c_2-p_val_d_1*p_val_c_2)/p_val_c_2

print(format(a2, '.3f'),'R1 +','R2 =', format(c2, '.3f'))

#======== Finding Corner Point C ========#
detc_2=np.array([[a1, c1],[a2, c2]])
denom=np.array([[a1, b1],[a2, b2]])

lamm2=np.linalg.det(detc_2)/np.linalg.det(denom)
lamm2=np.round(lamm2,4)
detc_1=np.array([[c1, b1],[c2, b2]])
denom=np.array([[a1, b1],[a2, b2]])

lamm1=np.linalg.det(detc_1)/np.linalg.det(denom)
lamm1=np.round(lamm1,4)

point_c=np.array([lamm1, lamm2])

#======== Finding Corner Point B ========#

lamm11=c1-(b1*p_val_d_2)
lamm12=c2-(b2*p_val_d_2)
if lamm11<lamm12:
    lamm1=np.round(lamm11,4)
else: 
    lamm1=np.round(lamm12,4)
        
lamm2=p_val_d_2
point_b=np.array([lamm1, lamm2])

#======== Finding Corner Point A ========#

lamm21=c1-(a1*p_val_d_1)
lamm22=c2-(a2*p_val_d_1)
if lamm21<lamm22:
    lamm2=np.round(lamm21,4)
else: 
    lamm2=np.round(lamm22,4)
        
lamm1=p_val_d_1
point_a=np.array([lamm1, lamm2])


## ---- Print Corner Points ---- ##
print('============================================')
print("The Corner Points can be shown as follow:")

print('Corner Point A =',point_a)
print('Corner Point B =',point_b)
print('Corner Point C =',point_c)
# Out:
# The information-theoretic outer-bounds can be respresented as:
# R1 =  0.6
# R2 =  0.8
# R1 + 1.900 R2 = 1.672
# 1.800 R1 + R2 = 1.440
# ============================================
# The Corner Points can be shown as follow:
# Corner Point A = [0.6  0.36]
# Corner Point B = [0.152 0.8  ]
# Corner Point C = [0.4397 0.6486]

# %% [markdown]
# # Generate P[t]

# %%
##===== Select arriving rates =====##

lambda_1=0.4397 #Arriving rate at Tx1
lambda_2=0.6486  #Arriving rate

if lambda_1<=point_c[0] and lambda_2<=point_c[1]:
    P_t=1
elif lambda_1<=point_b[0] and lambda_2>=point_c[1]:
    P_t=0
elif lambda_1<=point_c[0] and lambda_2>=point_c[1]:
    
    lam1_max=point_b[0]
    lam2_max=point_b[1]
    P_t=((lam2_max-lam1_max)-(lambda_2-lambda_1))/((lam2_max-lam1_max)-(point_c[0]-point_c[1]))
    
print('P[t]=',P_t)

lam1=np.array([lambda_1])
lam2=np.array([lambda_2])

## ---- Initial values for delivered stable rates ---- ##

out_lambda_1=np.zeros(len(lam1))
out_lambda_2=np.zeros(len(lam2))
# Out:
# P[t]= 1

# %% [markdown]
# # Transmission Protocol

# %%
## ---- Calculate number of iteration based on "communication_time", "erasure_probability", "reliability" and "accuracy" ---- ##
erasure_probability=erasure_probability11
beta=100  #beta
communication_time=10000
reliability=0.95
accuracy=0.0005
iters=np.round(1/(((1-reliability)/(erasure_probability*(1-erasure_probability)))*accuracy**2*communication_time))
iters=iters.astype(np.int64)


packet_num=communication_time-beta  # Time insterval when newly data bits are arriving

ib=-1
lambda_1_r=1
lambda_2_r=0
while ib<np.size(lam1,0)-1 and lambda_1_r!=lambda_2_r:
    ib=ib+1
    ia=0
    delta_1=1
    delta_2=1
    
    while ia<np.size(lam2,0) and (delta_1>=0.01 or delta_2>=0.01):
        packet_num=communication_time
        packet_num=np.round(packet_num)
        packet_num=packet_num.astype(np.int64)
        
        # ---- Initial values for errors ---- #
        delta_1=0
        delta_2=0
        rep=-1
        
        while rep<(iters-1) and delta_1<=(iters*0.01) and delta_2<=(iters*0.01):
            rep=rep+1
            print('repetition=',rep+1) # print current repetition number
            print('Communication_time=',communication_time)
            print('Number of iterations=',iters)     


            # ---- Arrival rates ---- #
    
            lambda_1=lam1[ia]
            lambda_2=lam2[ib]
            print('lambda_1=',lambda_1)
            print('lambda_2=',lambda_2)
            
            # ---- Generate Poisson sequences with lambda values ---- #
            
            arrived_pkt_1=poisson.rvs(lambda_1, size=packet_num)
            lambda_1_r=np.sum(arrived_pkt_1)/packet_num

            arrived_pkt_2=poisson.rvs(lambda_2, size=packet_num)
            lambda_2_r=np.sum(arrived_pkt_2)/packet_num
            
            # ---- Make sure that generated sequences has expected_value=lambdas ---- #
            
            while (lambda_1-0.01)>lambda_1_r or lambda_1_r>lambda_1:
                arrived_pkt_1=poisson.rvs(lambda_1, size=packet_num)
                lambda_1_r=np.sum(arrived_pkt_1)/packet_num
            
            while (lambda_2-0.01)>lambda_2_r or lambda_2_r>lambda_2:
                arrived_pkt_2=poisson.rvs(lambda_2, size=packet_num)
                lambda_2_r=np.sum(arrived_pkt_2)/packet_num
            
            pkt_ind_1=np.zeros((1, 6))-np.ones((1, 6))
            pkt_ind_2=np.zeros((1, 6))-np.ones((1, 6))


            # ----- initial value for all of the Queues(Q1) ----- #

            Q1_total=np.zeros((6, packet_num))
            number_of_packets_Q1=np.zeros((1, 6))
            for num_pkt1 in range(5):
                number_of_packets_Q1[0,num_pkt1]=np.count_nonzero(Q1_total[num_pkt1,:])

            # ----- initial value for all of the Queues(Q2) ----- #
            
            Q2_total=np.zeros((6, packet_num))
            number_of_packets_Q2=np.zeros((1, 6))
            for num_pkt2 in range(5):
                number_of_packets_Q2[0,num_pkt2]=np.count_nonzero(Q2_total[num_pkt2,:])

            # ----- Bernoulli Generators for C_ij(t) ----- #

            q11=1-erasure_probability11
            q12=1-erasure_probability12
            q21=1-erasure_probability21
            q22=1-erasure_probability22

            
            
            uu=1000   # uu is used to show every proceess for packet_num on every 1000 time instants
        
            for i in range(packet_num+beta):

                
                if i>=uu:
                    print(i)
                    uu=uu+1000

                if i>packet_num-1:
                    arrived_pkt_T1 =0
                    arrived_pkt_T2 =0
                else:
                        
                    arrived_pkt_T1 = arrived_pkt_1[i]
                    arrived_pkt_T2 = arrived_pkt_2[i]
                
                # ---- New arrived data bits join initial queues ---- #

                if arrived_pkt_T1!=0:
                    for p in range(arrived_pkt_T1):
                        Q_des_Q1=2
                        pkt_ind_1[0,(Q_des_Q1-1)]=pkt_ind_1[0,(Q_des_Q1-1)]+1
                        b1=pkt_ind_1[0,(Q_des_Q1-1)]
                        b1=b1.astype(np.int64)
                        Q1_total[(Q_des_Q1-1),b1]=1

                if arrived_pkt_T2!=0:
                    for p in range(arrived_pkt_T2):
                        Q_des_Q2=2
                        pkt_ind_2[0,(Q_des_Q2-1)]=pkt_ind_2[0,(Q_des_Q2-1)]+1
                        b2=pkt_ind_2[0,(Q_des_Q2-1)]
                        b2=b2.astype(np.int64)
                        Q2_total[(Q_des_Q2-1),b2]=1


                for num_pkt1 in range(5):
                    number_of_packets_Q1[0,num_pkt1]=np.count_nonzero(Q1_total[num_pkt1,:])

                for num_pkt2 in range(5):
                    number_of_packets_Q2[0,num_pkt2]=np.count_nonzero(Q2_total[num_pkt2,:])

                if np.sum(number_of_packets_Q1)==0 or np.sum(number_of_packets_Q2)==0:
                    if np.sum(number_of_packets_Q1)!=0:
                        data_q11= bernoulli.rvs(size=1,p=q11)
                        data_q12= bernoulli.rvs(size=1,p=q12)
                        Q_des_Q1,pointer_1=T1_select(number_of_packets_Q1,data_q11,data_q12)
                        
                        ## ----- Data movement from origin queue ----- ##
                        
                        a1=pkt_ind_1[0,(pointer_1)]
                        a1=a1.astype(np.int64)
                        val=Q1_total[(pointer_1),a1]
                        Q1_total[(pointer_1),a1]=0
                        pkt_ind_1[0,(pointer_1)]=pkt_ind_1[0,(pointer_1)]-1

                        ## ----- Data movement in destination queue ----- ##

                        pkt_ind_1[0,(Q_des_Q1-1)]=pkt_ind_1[0,(Q_des_Q1-1)]+1
                        b1=pkt_ind_1[0,(Q_des_Q1-1)]
                        b1=b1.astype(np.int64)
                        Q1_total[(Q_des_Q1-1),b1]=val

                    if np.sum(number_of_packets_Q2)!=0:
                        data_q22= bernoulli.rvs(size=1,p=q22)
                        data_q21= bernoulli.rvs(size=1,p=q21)
                        Q_des_Q2,pointer_2=T2_select(number_of_packets_Q2,data_q22,data_q21)
                        
                        ## ----- Data movement from origin queue ----- ##
                        
                        a2=pkt_ind_2[0,(pointer_2)]
                        a2=a2.astype(np.int64)
                        val=Q2_total[(pointer_2),a2]
                        Q2_total[(pointer_2),a2]=0
                        pkt_ind_2[0,(pointer_2)]=pkt_ind_2[0,(pointer_2)]-1

                        ## ----- Data movement in destination queue ----- ##

                        pkt_ind_2[0,(Q_des_Q2-1)]=pkt_ind_2[0,(Q_des_Q2-1)]+1
                        b2=pkt_ind_2[0,(Q_des_Q2-1)]
                        b2=b2.astype(np.int64)
                        Q2_total[(Q_des_Q2-1),b2]=val

                else:

                    pointer_1,pointer_2,control_num=ctrl_I_finder(number_of_packets_Q1,number_of_packets_Q2)

                    data_q11= bernoulli.rvs(size=1,p=q11)
                    data_q12= bernoulli.rvs(size=1,p=q12)
                    data_q21= bernoulli.rvs(size=1,p=q21)
                    data_q22= bernoulli.rvs(size=1,p=q22)
                    case_num=case_cal(data_q11,data_q12,data_q21,data_q22)
                    
                    ## ----- Data movement from origin queue ----- ## 
                    
                    a1=pkt_ind_1[0,(pointer_1)]
                    a1=a1.astype(np.int64)
                    val_1=Q1_total[(pointer_1),a1]
                    Q1_total[(pointer_1),a1]=0
                    pkt_ind_1[0,(pointer_1)]=pkt_ind_1[0,(pointer_1)]-1


                    a2=pkt_ind_2[0,(pointer_2)]
                    a2=a2.astype(np.int64)
                    val_2=Q2_total[(pointer_2),a2]
                    Q2_total[(pointer_2),a2]=0
                    pkt_ind_2[0,(pointer_2)]=pkt_ind_2[0,(pointer_2)]-1

                    ## ----- Data movement in destination queue ----- ##
                    
                    Q_des_Q1=control_I_T1[control_num,case_num]
                    Q_des_Q2=control_I_T2[control_num,case_num]                     
                    pkt_ind_1[0,(Q_des_Q1-1)]=pkt_ind_1[0,(Q_des_Q1-1)]+1
                    b1=pkt_ind_1[0,(Q_des_Q1-1)]
                    b1=b1.astype(np.int64)
                    Q1_total[(Q_des_Q1-1),b1]=val_1


                    
                    pkt_ind_2[0,(Q_des_Q2-1)]=pkt_ind_2[0,(Q_des_Q2-1)]+1
                    b2=pkt_ind_2[0,(Q_des_Q2-1)]
                    b2=b2.astype(np.int64)
                    Q2_total[(Q_des_Q2-1),b2]=val_2

                number_of_packets_Q1_c1=np.count_nonzero(Q1_total[4,:]) 
                number_of_packets_Q2_c1=np.count_nonzero(Q2_total[4,:])
                 ## --------- ##
                number_of_packets_Q1_1_2=np.count_nonzero(Q1_total[2,:]) 
                number_of_packets_Q2_1_2=np.count_nonzero(Q2_total[2,:])
                 ## --------- ##
                number_of_packets_Q1_2_1=np.count_nonzero(Q1_total[3,:]) 
                number_of_packets_Q2_2_1=np.count_nonzero(Q2_total[3,:])
                

              ##### ---------------- XOR Combination procedure for Q1 ---------------- #####
                    # ---- Q1_2_1 & Q1_1_2 -- Q1_c1 & Q1_2_1 -- Q1_c1 & Q1_1_2 ---- # 
                
                if number_of_packets_Q1_2_1!=0: 
                    if number_of_packets_Q1_1_2!=0:
                        pack=[3,2]
                        pack=np.asarray(pack)
                        val=0
                        for jj in range(len(pack)):
                            
                        ## ----- Data movement from origin queue ----- ##
                            
                            Q_des_Q1=pack[jj]
                            b1=pkt_ind_1[0,(Q_des_Q1)]
                            b1=b1.astype(np.int64)
                            val=Q1_total[(Q_des_Q1),b1]+val
                            Q1_total[(Q_des_Q1),b1]=0
                            pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]-1
                            
                        ## ----- Data movement in destination queue ----- ##
                            
                        Q_des_Q1=0
                        pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]+1
                        b1=pkt_ind_1[0,(Q_des_Q1)]
                        b1=b1.astype(np.int64)
                        Q1_total[(Q_des_Q1),b1]=val
                        
                if number_of_packets_Q1_c1!=0:
                    if number_of_packets_Q1_2_1!=0:
                        pack=[4,3]
                        pack=np.asarray(pack)
                        val=0
                        for jj in range(len(pack)):
                            
                        ## ----- Data movement from origin queue ----- ##
                            
                            Q_des_Q1=pack[jj]
                            b1=pkt_ind_1[0,(Q_des_Q1)]
                            b1=b1.astype(np.int64)
                            val=Q1_total[(Q_des_Q1),b1]+val
                            Q1_total[(Q_des_Q1),b1]=0
                            pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]-1
                            
                        ## ----- Data movement in destination queue ----- ##
                            
                        Q_des_Q1=0
                        pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]+1
                        b1=pkt_ind_1[0,(Q_des_Q1)]
                        b1=b1.astype(np.int64)
                        Q1_total[(Q_des_Q1),b1]=val
                
                if number_of_packets_Q1_c1!=0: 
                    if number_of_packets_Q1_1_2!=0:
                        pack=[4,2]
                        pack=np.asarray(pack)
                        val=0
                        for jj in range(len(pack)):
                            
                        ## ----- Data movement from origin queue ----- ##
                            
                            Q_des_Q1=pack[jj]
                            b1=pkt_ind_1[0,(Q_des_Q1)]
                            b1=b1.astype(np.int64)
                            val=Q1_total[(Q_des_Q1),b1]+val
                            Q1_total[(Q_des_Q1),b1]=0
                            pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]-1
                            
                        ## ----- Data movement in destination queue ----- ##
                            
                        Q_des_Q1=0
                        pkt_ind_1[0,(Q_des_Q1)]=pkt_ind_1[0,(Q_des_Q1)]+1
                        b1=pkt_ind_1[0,(Q_des_Q1)]
                        b1=b1.astype(np.int64)
                        Q1_total[(Q_des_Q1),b1]=val
                

                ##### ---------------- XOR Combination procedure for Q2 ---------------- #####
                      # ---- Q2_2_1 & Q2_1_2 -- Q2_c1 & Q2_1_2 -- Q2_c1 & Q2_1_2 ---- #
            
                if number_of_packets_Q2_1_2!=0: 
                    if number_of_packets_Q2_2_1!=0:
                        pack=[3,2]
                        pack=np.asarray(pack)
                        val=0
                        for jj in range(len(pack)):
                            
                        ## ----- Data movement from origin queue ----- ##
                            
                            Q_des_Q2=pack[jj]
                            b1=pkt_ind_2[0,(Q_des_Q2)]
                            b1=b1.astype(np.int64)
                            val=Q2_total[(Q_des_Q2),b1]+val
                            Q2_total[(Q_des_Q2),b1]=0
                            pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]-1
                            
                        ## ----- Data movement in destination queue ----- ##
                        
                        Q_des_Q2=0
                        pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]+1
                        b1=pkt_ind_2[0,(Q_des_Q2)]
                        b1=b1.astype(np.int64)
                        Q2_total[(Q_des_Q2),b1]=val
                        
                if number_of_packets_Q2_c1!=0:
                    if number_of_packets_Q2_1_2!=0:
                        pack=[4,2]
                        pack=np.asarray(pack)
                        val=0
                        for jj in range(len(pack)):
                            
                        ## ----- Data movement from origin queue ----- ##
                            
                            Q_des_Q2=pack[jj]
                            b1=pkt_ind_2[0,(Q_des_Q2)]
                            b1=b1.astype(np.int64)
                            val=Q2_total[(Q_des_Q2),b1]+val
                    
                            Q2_total[(Q_des_Q2),b1]=0
                            pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]-1
                            
                        ## ----- Data movement in destination queue ----- ##
                            
                        Q_des_Q2=0
                        pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]+1
                        b1=pkt_ind_2[0,(Q_des_Q2)]
                        b1=b1.astype(np.int64)
                        Q2_total[(Q_des_Q2),b1]=val
                
                if number_of_packets_Q2_c1!=0: 
                    if number_of_packets_Q2_2_1!=0:
                        pack=[3,4]
                        pack=np.asarray(pack)
                        val=0
                        for jj in range(len(pack)):
                            
                        ## ----- Data movement from origin queue ----- ##
                            
                            Q_des_Q2=pack[jj]
                            b1=pkt_ind_2[0,(Q_des_Q2)]
                            b1=b1.astype(np.int64)
                            val=Q2_total[(Q_des_Q2),b1]+val
            
                            Q2_total[(Q_des_Q2),b1]=0
                            pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]-1
                    
                        ## ----- Data movement in destination queue ----- ##
                        
                        Q_des_Q2=0
                        pkt_ind_2[0,(Q_des_Q2)]=pkt_ind_2[0,(Q_des_Q2)]+1
                        b1=pkt_ind_2[0,(Q_des_Q2)]
                        b1=b1.astype(np.int64)
                        Q2_total[(Q_des_Q2),b1]=val



            number_of_packets_Q1_F=np.sum(Q1_total[5,:]) 
            number_of_packets_Q2_F=np.sum(Q2_total[5,:])
            
            
            stable_rate_T1=(number_of_packets_Q1_F)/packet_num
            stable_rate_T2=(number_of_packets_Q2_F)/packet_num
            
            
            out_lambda_1[ib]=lambda_1_r
            out_lambda_2[ib]=lambda_2_r
            
    ##### ---------------- Error calculations ---------------- #####

            delta_1=delta_1+((lambda_1_r-stable_rate_T1)/lambda_1_r)
            if lambda_1_r==0:
                delta_1=0
            print('delta_1=',delta_1/(rep+1))
            
            delta_2=delta_2+((lambda_2_r-stable_rate_T2)/lambda_2_r)
            if lambda_2_r==0:
                delta_2=0
            print('delta_2=',delta_2/(rep+1))
            print('-------------------------------------')    
            
        delta_1=delta_1/(rep+1)
        delta_2=delta_2/(rep+1)
        
        
        if np.abs(delta_1)>0.01 or np.abs(delta_2)>0.01:
            out_lambda_1[ib]=0
            out_lambda_2[ib]=0
        print('Final error at T1=',delta_1)
        print('Final error at T2=',delta_2)
        print('Delivered Stable Rates by T1=',out_lambda_1)
        print('Delivered Stable Rates by T2=',out_lambda_2)
        ia=ia+1
        
## ---------------- Final delivered stable rates ---------------- ##

print('Delivered Stable Rates by T1=',out_lambda_1)
print('Delivered Stable Rates by T2=',out_lambda_2)
# Out:
# repetition= 1
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0
# delta_2= 0.002190923317683987
# -------------------------------------
# repetition= 2
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0
# delta_2= 0.0010954616588419936
# -------------------------------------
# repetition= 3
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0018331805682859862
# delta_2= 0.0010920648785044992
# -------------------------------------
# repetition= 4
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008197719176498749
# delta_2= 0.0008190486588783743
# -------------------------------------
# repetition= 5
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.006558175341198999
# delta_2= 0.0013732036531835736
# -------------------------------------
# repetition= 6
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0054651461176658325
# delta_2= 0.0011443363776529778
# -------------------------------------
# repetition= 7
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.005013271784097681
# delta_2= 0.0009808597522739811
# -------------------------------------
# repetition= 8
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011938100225273108
# delta_2= 0.0012461498782746446
# -------------------------------------
# repetition= 9
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010611644644687206
# delta_2= 0.001107688780688573
# -------------------------------------
# repetition= 10
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009550480180218486
# delta_2= 0.0009969199026197157
# -------------------------------------
# repetition= 11
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00947006439105589
# delta_2= 0.0011043806684586672
# -------------------------------------
# repetition= 12
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011953342891192403
# delta_2= 0.001295664250264722
# -------------------------------------
# repetition= 13
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.012410633315172772
# delta_2= 0.0012796747762290487
# -------------------------------------
# repetition= 14
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011524159506946146
# delta_2= 0.0013096527636213954
# -------------------------------------
# repetition= 15
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01075588220648307
# delta_2= 0.001222342579379969
# -------------------------------------
# repetition= 16
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011111314418045222
# delta_2= 0.001145946168168721
# -------------------------------------
# repetition= 17
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010905912829707327
# delta_2= 0.0010785375700411491
# -------------------------------------
# repetition= 18
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010300028783612476
# delta_2= 0.0010186188161499742
# -------------------------------------
# repetition= 19
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009757922005527608
# delta_2= 0.0009650072995105019
# -------------------------------------
# repetition= 20
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010407708747136535
# delta_2= 0.0009477310711309243
# -------------------------------------
# repetition= 21
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009912103568701461
# delta_2= 0.0009026010201246898
# -------------------------------------
# repetition= 22
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010127096968393706
# delta_2= 0.0011629220597307712
# -------------------------------------
# repetition= 23
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0112831396018139
# delta_2= 0.0011123602310468246
# -------------------------------------
# repetition= 24
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011324721316342974
# delta_2= 0.0010660118880865402
# -------------------------------------
# repetition= 25
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011128613197634212
# delta_2= 0.0010233714125630787
# -------------------------------------
# repetition= 26
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01070058961310982
# delta_2= 0.0009840109736183448
# -------------------------------------
# repetition= 27
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010304271479290937
# delta_2= 0.0009475661227435914
# -------------------------------------
# repetition= 28
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009936261783601975
# delta_2= 0.0013494663398160426
# -------------------------------------
# repetition= 29
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009593632066926044
# delta_2= 0.0014365456906482164
# -------------------------------------
# repetition= 30
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00995914501666253
# delta_2= 0.0013886608342932759
# -------------------------------------
# repetition= 31
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009999917354649996
# delta_2= 0.0013438653235096217
# -------------------------------------
# repetition= 32
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010594887095648596
# delta_2= 0.0014086905389864895
# -------------------------------------
# repetition= 33
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010760234891718975
# delta_2= 0.0013991935605904386
# -------------------------------------
# repetition= 34
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010667498343565335
# delta_2= 0.001358040808808367
# -------------------------------------
# repetition= 35
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010362712676606326
# delta_2= 0.0013192396428424137
# -------------------------------------
# repetition= 36
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01082852018408216
# delta_2= 0.0013169725350516874
# -------------------------------------
# repetition= 37
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010659607600154388
# delta_2= 0.0012813786827529934
# -------------------------------------
# repetition= 38
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011194990682743664
# delta_2= 0.0012923024977349305
# -------------------------------------
# repetition= 39
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01090793963959639
# delta_2= 0.0012591665362545476
# -------------------------------------
# repetition= 40
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010635241148606481
# delta_2= 0.001227687372848184
# -------------------------------------
# repetition= 41
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010375845023030713
# delta_2= 0.0011977437783884722
# -------------------------------------
# repetition= 42
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010352185642238273
# delta_2= 0.0011692260693792228
# -------------------------------------
# repetition= 43
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010111437138930406
# delta_2= 0.0011420347654401712
# -------------------------------------
# repetition= 44
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00988163174940926
# delta_2= 0.0011160794298619855
# -------------------------------------
# repetition= 45
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009662039932755722
# delta_2= 0.0010912776647539412
# -------------------------------------
# repetition= 46
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0094917471391865
# delta_2= 0.0010675542372592904
# -------------------------------------
# repetition= 47
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01007871343144511
# delta_2= 0.0010448403173176034
# -------------------------------------
# repetition= 48
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010410800254912155
# delta_2= 0.00102307281070682
# -------------------------------------
# repetition= 49
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011084632319680711
# delta_2= 0.0010021937737536195
# -------------------------------------
# repetition= 50
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01126877642659307
# delta_2= 0.0010037381789261932
# -------------------------------------
# repetition= 51
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011047820026071638
# delta_2= 0.0009840570381629344
# -------------------------------------
# repetition= 52
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010940808250118157
# delta_2= 0.0010453477213319907
# -------------------------------------
# repetition= 53
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010734377905776306
# delta_2= 0.0010256241794200664
# -------------------------------------
# repetition= 54
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010599626734579228
# delta_2= 0.0010066311390604357
# -------------------------------------
# repetition= 55
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010406906248495969
# delta_2= 0.0009883287547138822
# -------------------------------------
# repetition= 56
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010221068636915685
# delta_2= 0.0009706800269511344
# -------------------------------------
# repetition= 57
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010041751643285584
# delta_2= 0.0009536505527940969
# -------------------------------------
# repetition= 58
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010979825087141484
# delta_2= 0.0009505241648050331
# -------------------------------------
# repetition= 59
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01079372635685095
# delta_2= 0.0009344135857405411
# -------------------------------------
# repetition= 60
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010613830917570101
# delta_2= 0.0009188400259781987
# -------------------------------------
# repetition= 61
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010880477477456083
# delta_2= 0.0011440388842328582
# -------------------------------------
# repetition= 62
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011215793716556198
# delta_2= 0.0011255866441645863
# -------------------------------------
# repetition= 63
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011096162176106093
# delta_2= 0.001107720189495307
# -------------------------------------
# repetition= 64
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011095595702012268
# delta_2= 0.0011145918820234556
# -------------------------------------
# repetition= 65
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011241305423598523
# delta_2= 0.0011283466631862014
# -------------------------------------
# repetition= 66
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011224840603226142
# delta_2= 0.0011112505016227742
# -------------------------------------
# repetition= 67
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.011057305668849634
# delta_2= 0.0010946646732403447
# -------------------------------------
# repetition= 68
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01089469823254302
# delta_2= 0.0010785666633397514
# -------------------------------------
# repetition= 69
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0107898546290349
# delta_2= 0.001168247479535244
# -------------------------------------
# repetition= 70
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.01076373380660331
# delta_2= 0.0011515582298275977
# -------------------------------------
# repetition= 71
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010778926357484286
# delta_2= 0.0012940561443012392
# -------------------------------------
# repetition= 72
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010629219046963671
# delta_2= 0.0012760831422970553
# -------------------------------------
# repetition= 73
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010483613306594306
# delta_2= 0.0012586025513066847
# -------------------------------------
# repetition= 74
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010341942856505195
# delta_2= 0.0012415944087214592
# -------------------------------------
# repetition= 75
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010403146693692217
# delta_2= 0.001225039816605173
# -------------------------------------
# repetition= 76
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010266263184564688
# delta_2= 0.001208920871649842
# -------------------------------------
# repetition= 77
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010132935091258653
# delta_2= 0.0011932206005894543
# -------------------------------------
# repetition= 78
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.010003025667011747
# delta_2= 0.0011779229005818971
# -------------------------------------
# repetition= 79
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009937415597282052
# delta_2= 0.0012430413725956512
# -------------------------------------
# repetition= 80
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009813197902316027
# delta_2= 0.0012275033554382056
# -------------------------------------
# repetition= 81
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009692047310929408
# delta_2= 0.001212348993025388
# -------------------------------------
# repetition= 82
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009573851612015636
# delta_2= 0.0011975642492080055
# -------------------------------------
# repetition= 83
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009458504002232315
# delta_2= 0.0011831357642777885
# -------------------------------------
# repetition= 84
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0093459027641105
# delta_2= 0.0011690508147030529
# -------------------------------------
# repetition= 85
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009661700744579617
# delta_2= 0.0011552972757065464
# -------------------------------------
# repetition= 86
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009707649459910511
# delta_2= 0.0011418635864541447
# -------------------------------------
# repetition= 87
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009818418555367622
# delta_2= 0.001128738717644327
# -------------------------------------
# repetition= 88
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00972763434143444
# delta_2= 0.0011159121413074596
# -------------------------------------
# repetition= 89
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009644052531806013
# delta_2= 0.0011033738026410835
# -------------------------------------
# repetition= 90
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009646252716156717
# delta_2= 0.0011924364361580206
# -------------------------------------
# repetition= 91
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00969658740608654
# delta_2= 0.001179332739057383
# -------------------------------------
# repetition= 92
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009591189716889947
# delta_2= 0.0011665139049371939
# -------------------------------------
# repetition= 93
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009510341443087702
# delta_2= 0.0011539707446690522
# -------------------------------------
# repetition= 94
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009720698626925725
# delta_2= 0.0011763093122304949
# -------------------------------------
# repetition= 95
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009637689824382518
# delta_2= 0.0011851232219028348
# -------------------------------------
# repetition= 96
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0095372972220452
# delta_2= 0.001172778188341347
# -------------------------------------
# repetition= 97
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00962008669278801
# delta_2= 0.0011606876915543228
# -------------------------------------
# repetition= 98
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009566075936398475
# delta_2= 0.001148843939599687
# -------------------------------------
# repetition= 99
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009469448906737885
# delta_2= 0.0011372394553613061
# -------------------------------------
# repetition= 100
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009374754417670505
# delta_2= 0.001125867060807693
# -------------------------------------
# repetition= 101
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009339219203190098
# delta_2= 0.0011147198621858348
# -------------------------------------
# repetition= 102
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009247658230609803
# delta_2= 0.0011037912360859737
# -------------------------------------
# repetition= 103
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009157875140992231
# delta_2= 0.0010930748163181488
# -------------------------------------
# repetition= 104
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00925456071414037
# delta_2= 0.0010825644815458588
# -------------------------------------
# repetition= 105
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009457324816188774
# delta_2= 0.0010722543436263744
# -------------------------------------
# repetition= 106
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009571125020943093
# delta_2= 0.0010621387366110313
# -------------------------------------
# repetition= 107
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009481675254392223
# delta_2= 0.00105221220636233
# -------------------------------------
# repetition= 108
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00958414071690229
# delta_2= 0.001042469500747864
# -------------------------------------
# repetition= 109
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009496212820416948
# delta_2= 0.0010329055603740304
# -------------------------------------
# repetition= 110
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009499213843970743
# delta_2= 0.0010235155098251756
# -------------------------------------
# repetition= 111
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009413635340871909
# delta_2= 0.0010142946493763001
# -------------------------------------
# repetition= 112
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009482471522392988
# delta_2= 0.001005238447149726
# -------------------------------------
# repetition= 113
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00939855584520367
# delta_2= 0.000996342531688224
# -------------------------------------
# repetition= 114
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009408048752902343
# delta_2= 0.0010108016281389336
# -------------------------------------
# repetition= 115
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009410236273446284
# delta_2= 0.0010020120487638125
# -------------------------------------
# repetition= 116
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009474560659236226
# delta_2= 0.0009933740138606763
# -------------------------------------
# repetition= 117
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009393581508302584
# delta_2= 0.0009848836376738328
# -------------------------------------
# repetition= 118
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009424059399356708
# delta_2= 0.0009765371661681223
# -------------------------------------
# repetition= 119
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009358338717122347
# delta_2= 0.0010333523375153151
# -------------------------------------
# repetition= 120
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009280352561146326
# delta_2= 0.0010247410680360208
# -------------------------------------
# repetition= 121
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009412306088748126
# delta_2= 0.0010162721335894422
# -------------------------------------
# repetition= 122
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009637694354096553
# delta_2= 0.001110622891886576
# -------------------------------------
# repetition= 123
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009646301751116325
# delta_2= 0.0011015934374809942
# -------------------------------------
# repetition= 124
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009568508995058936
# delta_2= 0.0010927096194367925
# -------------------------------------
# repetition= 125
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009491960923098465
# delta_2= 0.0011298807701530839
# -------------------------------------
# repetition= 126
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009500017430524981
# delta_2= 0.001255640041659089
# -------------------------------------
# repetition= 127
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009499565743317919
# delta_2= 0.0012457531121972064
# -------------------------------------
# repetition= 128
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009425350385948248
# delta_2= 0.0012360206660081657
# -------------------------------------
# repetition= 129
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00935228565427423
# delta_2= 0.0012264391104577148
# -------------------------------------
# repetition= 130
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009311849327240827
# delta_2= 0.0012170049634541939
# -------------------------------------
# repetition= 131
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009240766507948913
# delta_2= 0.0012077148492293528
# -------------------------------------
# repetition= 132
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009284484544586502
# delta_2= 0.0011985654943109485
# -------------------------------------
# repetition= 133
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00924551219459637
# delta_2= 0.0011895537236770316
# -------------------------------------
# repetition= 134
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009176515834935202
# delta_2= 0.0011806764570824269
# -------------------------------------
# repetition= 135
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00915607944035821
# delta_2= 0.001171930705548483
# -------------------------------------
# repetition= 136
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00924984212576299
# delta_2= 0.0011633135680076854
# -------------------------------------
# repetition= 137
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009272070153802771
# delta_2= 0.0011548222280952205
# -------------------------------------
# repetition= 138
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009362087404774136
# delta_2= 0.0011464539510800378
# -------------------------------------
# repetition= 139
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0092947342579772
# delta_2= 0.0011382060809283828
# -------------------------------------
# repetition= 140
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00926953624675899
# delta_2= 0.0011489226262606136
# -------------------------------------
# repetition= 141
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009203794854938004
# delta_2= 0.0011528526076895534
# -------------------------------------
# repetition= 142
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00913897939821309
# delta_2= 0.0011447339273537116
# -------------------------------------
# repetition= 143
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009194595411371418
# delta_2= 0.0012460791133555957
# -------------------------------------
# repetition= 144
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009231318766991682
# delta_2= 0.001237425786179515
# -------------------------------------
# repetition= 145
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009167654499633119
# delta_2= 0.0012288918152403461
# -------------------------------------
# repetition= 146
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009104862345526044
# delta_2= 0.0012268670159254057
# -------------------------------------
# repetition= 147
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.009042924506440831
# delta_2= 0.0012185209818034643
# -------------------------------------
# repetition= 148
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008981823665181096
# delta_2= 0.0012102877319264138
# -------------------------------------
# repetition= 149
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008930817141799028
# delta_2= 0.0012021649954705319
# -------------------------------------
# repetition= 150
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008871278360853701
# delta_2= 0.001194150562167395
# -------------------------------------
# repetition= 151
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008812528173033478
# delta_2= 0.0011862422802987368
# -------------------------------------
# repetition= 152
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008754551014000363
# delta_2= 0.0011784380547704555
# -------------------------------------
# repetition= 153
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008781106748505099
# delta_2= 0.0012384292285875544
# -------------------------------------
# repetition= 154
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008724086574813507
# delta_2= 0.0012303874803499728
# -------------------------------------
# repetition= 155
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008667802145298581
# delta_2= 0.0012224494966057795
# -------------------------------------
# repetition= 156
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008612239311033847
# delta_2= 0.0012146132818839476
# -------------------------------------
# repetition= 157
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008598524756249677
# delta_2= 0.0012255497982469274
# -------------------------------------
# repetition= 158
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00871691228479374
# delta_2= 0.0012177931539542252
# -------------------------------------
# repetition= 159
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008837274546968208
# delta_2= 0.0012101340775142616
# -------------------------------------
# repetition= 160
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008949069904485015
# delta_2= 0.0012025707395297975
# -------------------------------------
# repetition= 161
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00889348561936399
# delta_2= 0.0011951013560544572
# -------------------------------------
# repetition= 162
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008838587559985199
# delta_2= 0.0011877241871899235
# -------------------------------------
# repetition= 163
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008784363096427009
# delta_2= 0.0012546739005132315
# -------------------------------------
# repetition= 164
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008730799906814649
# delta_2= 0.0012470234499003458
# -------------------------------------
# repetition= 165
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00867788596798547
# delta_2= 0.001239465732022162
# -------------------------------------
# repetition= 166
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008638004806544137
# delta_2= 0.001231999070985884
# -------------------------------------
# repetition= 167
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00858628022686423
# delta_2= 0.0012246218310398606
# -------------------------------------
# repetition= 168
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00858702617898648
# delta_2= 0.001217332415378909
# -------------------------------------
# repetition= 169
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00853621537319366
# delta_2= 0.0012101292649920516
# -------------------------------------
# repetition= 170
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008486002341586639
# delta_2= 0.0012030108575509218
# -------------------------------------
# repetition= 171
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008489831379498396
# delta_2= 0.0011959757063371738
# -------------------------------------
# repetition= 172
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00844047189473387
# delta_2= 0.0011890223592073066
# -------------------------------------
# repetition= 173
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008391683039851015
# delta_2= 0.0011821493975933915
# -------------------------------------
# repetition= 174
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008413348895896351
# delta_2= 0.001175355435538257
# -------------------------------------
# repetition= 175
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00836527261649123
# delta_2= 0.0011686391187637527
# -------------------------------------
# repetition= 176
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008381539425379073
# delta_2= 0.0011619991237707768
# -------------------------------------
# repetition= 177
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008334186095292186
# delta_2= 0.0012177698125258065
# -------------------------------------
# repetition= 178
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008372878320678309
# delta_2= 0.0012109284090846503
# -------------------------------------
# repetition= 179
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008326102464138207
# delta_2= 0.0012041634459054064
# -------------------------------------
# repetition= 180
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00829517553378827
# delta_2= 0.0011974736489837096
# -------------------------------------
# repetition= 181
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008481237973182922
# delta_2= 0.0011908577724699875
# -------------------------------------
# repetition= 182
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008481872128687921
# delta_2= 0.0011843145978959765
# -------------------------------------
# repetition= 183
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008449344505495022
# delta_2= 0.0011778429334265996
# -------------------------------------
# repetition= 184
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008505871767512871
# delta_2= 0.0011714416131362378
# -------------------------------------
# repetition= 185
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00850841210548464
# delta_2= 0.0011651094963084742
# -------------------------------------
# repetition= 186
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008462667954379884
# delta_2= 0.001214081878601115
# -------------------------------------
# repetition= 187
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008455365289367531
# delta_2= 0.0012075894621380073
# -------------------------------------
# repetition= 188
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008514422997669134
# delta_2= 0.0012011661139351456
# -------------------------------------
# repetition= 189
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008469373140538609
# delta_2= 0.0011948107376709384
# -------------------------------------
# repetition= 190
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008535221785775047
# delta_2= 0.0011885222601042494
# -------------------------------------
# repetition= 191
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# ...
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00848687323968238
# delta_2= 0.0010520389581327382
# -------------------------------------
# repetition= 370
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008491972079530273
# delta_2= 0.0010630105397690518
# -------------------------------------
# repetition= 371
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008469082666916984
# delta_2= 0.0010601452822494586
# -------------------------------------
# repetition= 372
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00844631631566183
# delta_2= 0.001057295429340186
# -------------------------------------
# repetition= 373
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008429215037678402
# delta_2= 0.001086615735080306
# -------------------------------------
# repetition= 374
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008406677029556267
# delta_2= 0.001083710345414316
# -------------------------------------
# repetition= 375
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0084491667158032
# delta_2= 0.0010808204511598778
# -------------------------------------
# repetition= 376
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008454755258355841
# delta_2= 0.0010779459286833887
# -------------------------------------
# repetition= 377
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008437186946878776
# delta_2= 0.0010750866556630085
# -------------------------------------
# repetition= 378
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008489773534657064
# delta_2= 0.0010722425110713074
# -------------------------------------
# repetition= 379
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00846737307678198
# delta_2= 0.0010694133751581905
# -------------------------------------
# repetition= 380
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008445090516053607
# delta_2= 0.00106659912943409
# -------------------------------------
# repetition= 381
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00843376072563607
# delta_2= 0.001063799656653423
# -------------------------------------
# repetition= 382
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008431989739173343
# delta_2= 0.0010703092872453258
# -------------------------------------
# repetition= 383
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008469056532096054
# delta_2= 0.0010675147460253642
# -------------------------------------
# repetition= 384
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008447001697377055
# delta_2= 0.0010647347597075897
# -------------------------------------
# repetition= 385
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008425061433228024
# delta_2= 0.0010619692148771803
# -------------------------------------
# repetition= 386
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008436841675281127
# delta_2= 0.001059217999294597
# -------------------------------------
# repetition= 387
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008420963533786343
# delta_2= 0.001056481001880399
# -------------------------------------
# repetition= 388
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008399260019524008
# delta_2= 0.001053758112700295
# -------------------------------------
# repetition= 389
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00840888871167149
# delta_2= 0.0010737072657804841
# -------------------------------------
# repetition= 390
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00838732745856464
# delta_2= 0.0010709541702272007
# -------------------------------------
# repetition= 391
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008365876493197467
# delta_2= 0.0010682151570041132
# -------------------------------------
# repetition= 392
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008344534971531146
# delta_2= 0.0010654901183382865
# -------------------------------------
# repetition= 393
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008371026531926156
# delta_2= 0.0010627789475537107
# -------------------------------------
# repetition= 394
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008388112695115113
# delta_2= 0.0010672053936009365
# -------------------------------------
# repetition= 395
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00836687696677305
# delta_2= 0.0010645036077943518
# -------------------------------------
# repetition= 396
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00839904585877974
# delta_2= 0.0010734956363125923
# -------------------------------------
# repetition= 397
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008377889571981807
# delta_2= 0.0010707916170775479
# -------------------------------------
# repetition= 398
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008372427648729709
# delta_2= 0.0010681011858788606
# -------------------------------------
# repetition= 399
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008421557491810176
# delta_2= 0.0010654242405508433
# -------------------------------------
# repetition= 400
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008423078268143164
# delta_2= 0.0010627606799494664
# -------------------------------------
# repetition= 401
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00840207308542959
# delta_2= 0.0010601104039396172
# -------------------------------------
# repetition= 402
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008397740918625827
# delta_2= 0.0010655887096805419
# -------------------------------------
# repetition= 403
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008396781230231633
# delta_2= 0.0010656238419907533
# -------------------------------------
# repetition= 404
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008376561727656261
# delta_2= 0.0010629861592135485
# -------------------------------------
# repetition= 405
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008355878859192912
# delta_2= 0.0010603615020303052
# -------------------------------------
# repetition= 406
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00833758165442338
# delta_2= 0.001057749774192792
# -------------------------------------
# repetition= 407
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008336229975826306
# delta_2= 0.0010585707724669125
# -------------------------------------
# repetition= 408
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00835876832426407
# delta_2= 0.001055976236259886
# -------------------------------------
# repetition= 409
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008338331237896675
# delta_2= 0.0010533943872714753
# -------------------------------------
# repetition= 410
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008367633261677122
# delta_2= 0.0010651790008469819
# -------------------------------------
# repetition= 411
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008384577725226133
# delta_2= 0.0010712419904773836
# -------------------------------------
# repetition= 412
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008364226808417332
# delta_2= 0.001068641888558749
# -------------------------------------
# repetition= 413
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008375701920929304
# delta_2= 0.001075860296181513
# -------------------------------------
# repetition= 414
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008428566556333785
# delta_2= 0.001074381596229936
# -------------------------------------
# repetition= 415
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00840825675740286
# delta_2= 0.0010717927249137193
# -------------------------------------
# repetition= 416
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008388044601736026
# delta_2= 0.001069216300094215
# -------------------------------------
# repetition= 417
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008403738093447766
# delta_2= 0.0010840457248415987
# -------------------------------------
# repetition= 418
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008467642800017324
# delta_2= 0.0010814523140166188
# -------------------------------------
# repetition= 419
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.0084474336286569
# delta_2= 0.0010788712822409228
# -------------------------------------
# repetition= 420
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008447203383562325
# delta_2= 0.0010763025410927302
# -------------------------------------
# repetition= 421
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008427138767449351
# delta_2= 0.001073746002990372
# -------------------------------------
# repetition= 422
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008416872162510292
# delta_2= 0.001073776507870497
# -------------------------------------
# repetition= 423
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008396974119572916
# delta_2= 0.0010712380291284863
# -------------------------------------
# repetition= 424
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.00837716993532864
# delta_2= 0.001068711524342806
# -------------------------------------
# repetition= 425
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008357458947245513
# delta_2= 0.0010698653548543212
# -------------------------------------
# repetition= 426
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008337840499012542
# delta_2= 0.0010673539338335364
# -------------------------------------
# repetition= 427
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008332257134820496
# delta_2= 0.0010648542759088679
# -------------------------------------
# repetition= 428
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# delta_1= 0.008314958648773667
# delta_2= 0.001062366298628707
# -------------------------------------
# repetition= 429
# Communication_time= 10000
# Number of iterations= 1920
# lambda_1= 0.4397
# lambda_2= 0.6486
# 1000
# 2000
# 3000
# 4000
# 5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-6ec0a8016bf1> in <module>
#     129
#     130                 for num_pkt2 in range(5):
# --> 131                     number_of_packets_Q2[0,num_pkt2]=np.count_nonzero(Q2_total[num_pkt2,:])
#     132
#     133                 if np.sum(number_of_packets_Q1)==0 or np.sum(number_of_packets_Q2)==0:
#
# <__array_function__ internals> in count_nonzero(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\core\numeric.py in count_nonzero(a, axis)
#     450     """
#     451     if axis is None:
# --> 452         return multiarray.count_nonzero(a)
#     453
#     454     a = asanyarray(a)
#
# KeyboardInterrupt:
